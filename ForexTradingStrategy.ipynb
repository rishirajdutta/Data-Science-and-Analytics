# %% [markdown]
# ## Written by <font color = 'blue'>Rishi Raj Dutta</font>
#
# ### Importing all the libraries required

# %%
import numpy as np
import pandas as pd
import missingno as msno
import matplotlib.pyplot as plt
from pylab import rcParams
import seaborn as sns
import datetime 
color = sns.color_palette()
# %matplotlib inline
rcParams['figure.figsize'] = 10, 10
# This will give us a good resolution for our visualization
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# ### Loading the data of forex rates of countires listed below with respect to US dollars:
# ###### India = DEXINUS
# ###### China = DEXCHUS
# ###### Mexico = DEXMXUS
# ###### Brazil = DEXBZUS
# ###### Europe = DEXUSEU
# ###### United Kingdom = DEXUSUK
# ###### Australia = DEXUSAL
# ###### Switzerland = DEXSZUS

# %%
# Importing the dataset
fd = pd.read_excel('C:\\Users\\rishi\\Desktop\\Fall 2018\\ML in Finance\\IND_CHN_600.xlsx')

# %% [markdown]
# ### Displaying the data set

# %%
fd
# Out:
#     observation_date  DEXINUS  DEXCHUS  DEXMXUS  DEXBZUS  DEXUSEU  DEXUSUK  \
# 0         2016-05-20    67.42   6.5485  18.3770   3.5386   1.1207   1.4513
# 1         2016-05-23    67.47   6.5533  18.4710   3.5753   1.1192   1.4444
# 2         2016-05-24    67.59   6.5552  18.4435   3.5518   1.1145   1.4623
# 3         2016-05-25    67.28   6.5538  18.4500   3.6072   1.1154   1.4694
# 4         2016-05-26    66.90   6.5540  18.4500   3.5775   1.1184   1.4673
# 5         2016-05-27    66.96   6.5615  18.4280   3.6122   1.1140   1.4644
# 6         2016-05-30      NaN      NaN      NaN      NaN      NaN      NaN
# 7         2016-05-31    67.12   6.5798  18.4130   3.6074   1.1135   1.4530
# 8         2016-06-01    67.44   6.5748  18.5475   3.6030   1.1165   1.4395
# 9         2016-06-02    67.22   6.5815  18.6320   3.5978   1.1157   1.4419
# 10        2016-06-03    66.99   6.5638  18.6120   3.5332   1.1330   1.4521
# 11        2016-06-06    66.81   6.5611  18.6140   3.5094   1.1354   1.4450
# 12        2016-06-07    66.64   6.5710  18.4360   3.4604   1.1350   1.4564
# 13        2016-06-08    66.51   6.5600  18.1250   3.3770   1.1400   1.4546
# 14        2016-06-09    66.68   6.5590  18.2885   3.3934   1.1329   1.4467
# 15        2016-06-10    66.84   6.5590  18.5260   3.4298   1.1281   1.4342
# 16        2016-06-13    67.17   6.5823  18.8145   3.4599   1.1282   1.4223
# 17        2016-06-14    67.34   6.5930  18.9785   3.4959   1.1206   1.4130
# 18        2016-06-15    67.08   6.5785  18.8630   3.4715   1.1239   1.4185
# 19        2016-06-16    67.43   6.5899  18.9875   3.4952   1.1158   1.4075
# 20        2016-06-17    67.11   6.5849  18.8615   3.4301   1.1256   1.4285
# 21        2016-06-20    67.54   6.5768  18.6660   3.3937   1.1318   1.4688
# 22        2016-06-21    67.73   6.5893  18.6550   3.4038   1.1262   1.4668
# 23        2016-06-22    67.49   6.5750  18.5300   3.3794   1.1286   1.4682
# 24        2016-06-23    67.29   6.5740  18.3010   3.3440   1.1373   1.4800
# 25        2016-06-24    67.82   6.6150  18.8545   3.3895   1.1126   1.3639
# 8     0.7242   0.9892
# 9     0.7225   0.9902
# 10    0.7339   0.9781
# 11    0.7362   0.9720
# 12    0.7452   0.9663
# 13    0.7479   0.9594
# 14    0.7431   0.9639
# 15    0.7395   0.9632
# 16    0.7394   0.9662
# 17    0.7360   0.9640
# 18    0.7404   0.9647
# 19    0.7312   0.9662
# 20    0.7385   0.9610
# 21    0.7458   0.9616
# 22    0.7461   0.9596
# 23    0.7491   0.9584
# 24    0.7598   0.9566
# 25    0.7451   0.9702
# 26    0.7357   0.9787
# 27    0.7353   0.9812
# 28    0.7444   0.9794
# 29    0.7432   0.9792
# ..       ...      ...
# 571   0.7408   0.9885
# 572   0.7438   0.9895
# 573   0.7402   0.9923
# 574   0.7379   0.9943
# 575   0.7406   0.9926
# 576   0.7393   0.9963
# 577   0.7428   0.9944
# 578   0.7420   0.9943
# 579   0.7394   0.9906
# 580   0.7298   0.9954
# 581   0.7270   0.9934
# 582   0.7240   0.9930
# 583   0.7233   0.9942
# 584   0.7276   0.9962
# 585   0.7282   0.9948
# 586   0.7308   0.9943
# 587   0.7352   0.9876
# 588   0.7352   0.9836
# 589   0.7264   0.9848
# 590   0.7332   0.9824
# 591   0.7346   0.9802
# 592   0.7352   0.9752
# 593   0.7292   0.9732
# 594   0.7262   0.9709
# 595   0.7192   0.9698
# 596      NaN      NaN
# 597   0.7174   0.9753
# 598   0.7189   0.9716
# 599   0.7198   0.9682
# 600   0.7135   0.9684
#
# [601 rows x 9 columns]

# %% [markdown]
# ### Checking for Null Values

# %%
fd.isnull().sum()
# Out:
# observation_date     0
# DEXINUS             24
# DEXCHUS             24
# DEXMXUS             24
# DEXBZUS             24
# DEXUSEU             24
# DEXUSUK             24
# DEXUSAL             24
# DEXSZUS             24
# dtype: int64

# %%
fd.shape
# Out:
# (601, 9)

# %% [markdown]
# ### <font color="Red"> Dropping all the Null Values </font>
# ### <font color="green"> Reason - All the null values are the recording on the days on which the forex/stock market was closed </font>
# ### <font color="green"> such as holidays, weekends and events. </font>

# %%
fd.dropna(inplace = True)

# %% [markdown]
# ### Checking for any remaining null values and verifying a uniform dataset

# %%
fd.isnull().sum()
# Out:
# observation_date    0
# DEXINUS             0
# DEXCHUS             0
# DEXMXUS             0
# DEXBZUS             0
# DEXUSEU             0
# DEXUSUK             0
# DEXUSAL             0
# DEXSZUS             0
# dtype: int64

# %% [markdown]
# ### Slicing the independent (X) and dependant variables (Y) and transforming them into a matrix

# %%
Y = fd.iloc[:, 6]
Y = pd.DataFrame(Y)
Y = np.matrix(Y)
X = fd.iloc[:, [5,7,8]]
X = pd.DataFrame(X)
X = np.matrix(X)

# %% [markdown]
# ###        Y = United Kingdom            and               X = Europe, Australia and Switzerland

# %%
Y
# Out:
# matrix([[ 1.4513],
#         [ 1.4444],
#         [ 1.4623],
#         [ 1.4694],
#         [ 1.4673],
#         [ 1.4644],
#         [ 1.453 ],
#         [ 1.4395],
#         [ 1.4419],
#         [ 1.4521],
#         [ 1.445 ],
#         [ 1.4564],
#         [ 1.4546],
#         [ 1.4467],
#         [ 1.4342],
#         [ 1.4223],
#         [ 1.413 ],
#         [ 1.4185],
#         [ 1.4075],
#         [ 1.4285],
#         [ 1.4688],
#         [ 1.4668],
#         [ 1.4682],
#         [ 1.48  ],
#         [ 1.3639],
#         [ 1.3217],
#         [ 1.3294],
#         [ 1.351 ],
#         [ 1.3242],
#         [ 1.3281],
#         [ 1.3021],
#         [ 1.2921],
#         [ 1.2926],
#         [ 1.2938],
#         [ 1.2986],
#         [ 1.3237],
#         [ 1.318 ],
#         [ 1.3332],
#         [ 1.3194],
#         [ 1.3279],
#         [ 1.3123],
#         [ 1.3179],
#         [ 1.3216],
#         [ 1.3091],
#         [ 1.313 ],
#         [ 1.3133],
#         [ 1.3094],
#         [ 1.3151],
#         [ 1.327 ],
#         [ 1.3209],
#         [ 1.3326],
#         [ 1.3335],
#         [ 1.3143],
#         [ 1.3069],
#         [ 1.3042],
#         [ 1.301 ],
#         [ 1.2998],
#         [ 1.296 ],
#         [ 1.2934],
#         [ 1.2874],
#         [ 1.3019],
#         [ 1.3012],
#         [ 1.3147],
#         [ 1.3061],
#         [ 1.3133],
#         [ 1.3179],
#         [ 1.3236],
#         [ 1.3177],
#         [ 1.3168],
#         [ 1.3089],
#         [ 1.3084],
#         [ 1.3129],
#         [ 1.3273],
#         [ 1.3299],
#         [ 1.3429],
#         [ 1.3339],
#         [ 1.3301],
#         [ 1.3257],
#         [ 1.3313],
#         [ 1.3184],
#         [ 1.3204],
#         [ 1.3215],
#         [ 1.309 ],
#         [ 1.3051],
#         [ 1.2974],
#         [ 1.2978],
#         [ 1.3092],
#         [ 1.2959],
#         [ 1.2978],
#         [ 1.3005],
#         [ 1.2996],
#         [ 1.2991],
#         [ 1.3015],
#         [ 1.284 ],
#         [ 1.2746],
#         [ 1.2745],
#         [ 1.2647],
#         [ 1.2434],
#         [ 1.2218],
#         [ 1.2195],
#         [ 1.2201],
#         [ 1.2189],
#         [ 1.2186],
#         [ 1.231 ],
#         [ 1.2279],
#         [ 1.2256],
#         [ 1.221 ],
#         [ 1.2204],
#         [ 1.2164],
#         [ 1.2234],
#         [ 1.2173],
#         [ 1.2155],
#         [ 1.2212],
#         [ 1.2218],
#         [ 1.2315],
#         [ 1.2454],
#         [ 1.2546],
#         [ 1.2403],
#         [ 1.2372],
#         [ 1.2474],
#         [ 1.2523],
#         [ 1.2469],
#         [ 1.2422],
#         [ 1.245 ],
#         [ 1.245 ],
#         [ 1.2327],
#         [ 1.2474],
#         [ 1.2424],
#         [ 1.2458],
#         [ 1.2462],
#         [ 1.2411],
#         [ 1.2505],
#         [ 1.2481],
#         [ 1.2596],
#         [ 1.2685],
#         [ 1.2708],
#         [ 1.2706],
#         [ 1.2604],
#         [ 1.2574],
#         [ 1.259 ],
#         [ 1.2677],
#         [ 1.2685],
#         [ 1.2706],
#         [ 1.2389],
#         [ 1.2478],
#         [ 1.2419],
#         [ 1.2358],
#         [ 1.2348],
#         [ 1.2301],
#         [ 1.2252],
#         [ 1.2261],
#         [ 1.2222],
#         [ 1.2237],
#         [ 1.2337],
#         [ 1.2256],
#         [ 1.2299],
#         [ 1.2415],
#         [ 1.2314],
#         [ 1.2167],
#         [ 1.2165],
#         [ 1.2118],
#         [ 1.2211],
#         [ 1.2198],
#         [ 1.2388],
#         [ 1.2309],
#         [ 1.2319],
#         [ 1.2485],
#         [ 1.2531],
#         [ 1.262 ],
#         [ 1.2579],
#         [ 1.2531],
#         [ 1.2478],
#         [ 1.2585],
#         [ 1.2643],
#         [ 1.2541],
#         [ 1.2504],
#         [ 1.245 ],
#         [ 1.2486],
#         [ 1.2543],
#         [ 1.2516],
#         [ 1.2502],
#         [ 1.251 ],
#         [ 1.2465],
#         [ 1.2465],
#         [ 1.2477],
#         [ 1.2428],
#         [ 1.2465],
#         [ 1.2456],
#         [ 1.2548],
#         [ 1.2499],
#         [ 1.2473],
#         [ 1.2427],
#         [ 1.2318],
#         [ 1.2267],
#         [ 1.2249],
#         [ 1.2243],
#         [ 1.2209],
#         [ 1.2152],
#         [ 1.2166],
#         [ 1.2158],
#         [ 1.2234],
#         [ 1.2168],
#         [ 1.2222],
#         [ 1.237 ],
#         [ 1.2372],
#         [ 1.2365],
#         [ 1.2479],
#         [ 1.2476],
#         [ 1.2526],
#         [ 1.2491],
#         [ 1.2583],
#         [ 1.2503],
#         [ 1.2411],
#         [ 1.2489],
#         [ 1.2537],
#         [ 1.2479],
#         [ 1.2437],
#         [ 1.2488],
#         [ 1.2486],
#         [ 1.2398],
#         [ 1.2418],
#         [ 1.2484],
#         [ 1.25  ],
#         [ 1.2522],
#         [ 1.2531],
#         [ 1.2587],
#         [ 1.2769],
#         [ 1.2789],
#         [ 1.283 ],
#         [ 1.2783],
#         [ 1.2783],
#         [ 1.2836],
#         [ 1.2838],
#         [ 1.2889],
#         [ 1.2938],
#         [ 1.2917],
#         [ 1.2921],
#         [ 1.2916],
#         [ 1.291 ],
#         [ 1.295 ],
#         [ 1.2942],
#         [ 1.2939],
#         [ 1.2939],
#         [ 1.2885],
#         [ 1.288 ],
#         [ 1.2917],
#         [ 1.2912],
#         [ 1.2944],
#         [ 1.3009],
#         [ 1.3018],
#         [ 1.3006],
#         [ 1.2984],
#         [ 1.2935],
#         [ 1.2954],
#         [ 1.2795],
#         [ 1.2858],
#         [ 1.2905],
#         [ 1.2894],
#         [ 1.2885],
#         [ 1.2917],
#         [ 1.2901],
#         [ 1.2941],
#         [ 1.2939],
#         [ 1.2737],
#         [ 1.2658],
#         [ 1.2739],
#         [ 1.2808],
#         [ 1.2768],
#         [ 1.2778],
#         [ 1.2743],
#         [ 1.2628],
#         [ 1.2667],
#         [ 1.2659],
#         [ 1.2727],
#         [ 1.2732],
#         [ 1.2791],
#         [ 1.2936],
#         [ 1.2984],
#         [ 1.2995],
#         [ 1.2951],
#         [ 1.2934],
#         [ 1.2967],
#         [ 1.288 ],
#         [ 1.2884],
#         [ 1.2851],
#         [ 1.2889],
#         [ 1.2921],
#         [ 1.3079],
#         [ 1.3058],
#         [ 1.3026],
#         [ 1.3036],
#         [ 1.2976],
#         [ 1.2968],
#         [ 1.3028],
#         [ 1.3046],
#         [ 1.3048],
#         [ 1.3065],
#         [ 1.3124],
#         [ 1.3196],
#         [ 1.3206],
#         [ 1.3236],
#         [ 1.3144],
#         [ 1.3036],
#         [ 1.3021],
#         [ 1.2968],
#         [ 1.2997],
#         [ 1.2978],
#         [ 1.2988],
#         [ 1.2975],
#         [ 1.2862],
#         [ 1.286 ],
#         [ 1.2888],
#         [ 1.2847],
#         [ 1.2903],
#         [ 1.2834],
#         [ 1.2787],
#         [ 1.2802],
#         [ 1.2873],
#         [ 1.2927],
#         [ 1.2937],
#         [ 1.2934],
#         [ 1.2888],
#         [ 1.2972],
#         [ 1.3013],
#         [ 1.3073],
#         [ 1.3094],
#         [ 1.3211],
#         [ 1.3173],
#         [ 1.328 ],
#         [ 1.3218],
#         [ 1.3398],
#         [ 1.3578],
#         [ 1.3485],
#         [ 1.3517],
#         [ 1.3564],
#         [ 1.3576],
#         [ 1.3531],
#         [ 1.3457],
#         [ 1.3422],
#         [ 1.3401],
#         [ 1.3435],
#         [ 1.3402],
#         [ 1.3268],
#         [ 1.3251],
#         [ 1.3268],
#         [ 1.3132],
#         [ 1.3063],
#         [ 1.3215],
#         [ 1.321 ],
#         [ 1.3174],
#         [ 1.3304],
#         [ 1.3285],
#         [ 1.3182],
#         [ 1.3183],
#         [ 1.3181],
#         [ 1.3179],
#         [ 1.3201],
#         [ 1.3124],
#         [ 1.3252],
#         [ 1.3181],
#         [ 1.3108],
#         [ 1.3195],
#         [ 1.3281],
#         [ 1.3257],
#         [ 1.3068],
#         [ 1.3067],
#         [ 1.3145],
#         [ 1.3152],
#         [ 1.3108],
#         [ 1.3133],
#         [ 1.3101],
#         [ 1.3128],
#         [ 1.3165],
#         [ 1.3197],
#         [ 1.3222],
#         [ 1.3241],
#         [ 1.3232],
#         [ 1.3291],
#         [ 1.3336],
#         [ 1.3333],
#         [ 1.3231],
#         [ 1.3436],
#         [ 1.3506],
#         [ 1.3505],
#         [ 1.3465],
#         [ 1.345 ],
#         [ 1.3382],
#         [ 1.3432],
#         [ 1.3367],
#         [ 1.3363],
#         [ 1.3323],
#         [ 1.3365],
#         [ 1.344 ],
#         [ 1.3316],
#         [ 1.3398],
#         [ 1.3356],
#         [ 1.3408],
#         [ 1.3372],
#         [ 1.3379],
#         [ 1.3369],
#         [ 1.3403],
#         [ 1.345 ],
#         [ 1.3529],
#         [ 1.3596],
#         [ 1.3522],
#         [ 1.3539],
#         [ 1.3562],
#         [ 1.3566],
#         [ 1.3518],
#         [ 1.3513],
#         [ 1.3543],
#         [ 1.3689],
#         [ 1.3774],
#         [ 1.3824],
#         [ 1.3889],
#         [ 1.3857],
#         [ 1.3944],
#         [ 1.3968],
#         [ 1.4198],
#         [ 1.4264],
#         [ 1.4179],
#         [ 1.4042],
#         [ 1.4124],
#         [ 1.419 ],
#         [ 1.4247],
#         [ 1.4126],
#         [ 1.4022],
#         [ 1.3951],
#         [ 1.3881],
#         [ 1.3915],
#         [ 1.3794],
#         [ 1.382 ],
#         [ 1.3892],
#         [ 1.3955],
#         [ 1.4061],
#         [ 1.4055],
#         [ 1.4021],
#         [ 1.3946],
#         [ 1.3939],
#         [ 1.3979],
#         [ 1.3952],
#         [ 1.3906],
#         [ 1.3794],
#         [ 1.3755],
#         [ 1.3769],
#         [ 1.3856],
#         [ 1.3886],
#         [ 1.3888],
#         [ 1.3824],
#         [ 1.3863],
#         [ 1.3898],
#         [ 1.3987],
#         [ 1.3946],
#         [ 1.3951],
#         [ 1.3919],
#         [ 1.4032],
#         [ 1.4013],
#         [ 1.4064],
#         [ 1.4098],
#         [ 1.4151],
#         [ 1.4236],
#         [ 1.4161],
#         [ 1.411 ],
#         [ 1.4029],
#         [ 1.4027],
#         [ 1.4032],
#         [ 1.4068],
#         [ 1.4076],
#         [ 1.3991],
#         [ 1.4088],
#         [ 1.4136],
#         [ 1.4161],
#         [ 1.4194],
#         [ 1.4244],
#         [ 1.4255],
#         [ 1.4332],
#         [ 1.4301],
#         [ 1.4227],
#         [ 1.4193],
#         [ 1.4033],
#         [ 1.3953],
#         [ 1.3975],
#         [ 1.3941],
#         [ 1.3927],
#         [ 1.3785],
#         [ 1.3751],
#         [ 1.3611],
#         [ 1.361 ],
#         [ 1.3569],
#         [ 1.3535],
#         [ 1.3567],
#         [ 1.3521],
#         [ 1.3567],
#         [ 1.3487],
#         [ 1.3549],
#         [ 1.3595],
#         [ 1.3512],
#         [ 1.3478],
#         [ 1.3507],
#         [ 1.3476],
#         [ 1.3418],
#         [ 1.3445],
#         [ 1.3341],
#         [ 1.3384],
#         [ 1.3321],
#         [ 1.3258],
#         [ 1.3296],
#         [ 1.3289],
#         [ 1.3358],
#         [ 1.3314],
#         [ 1.336 ],
#         [ 1.3429],
#         [ 1.3427],
#         [ 1.3406],
#         [ 1.3386],
#         [ 1.3416],
#         [ 1.3378],
#         [ 1.3333],
#         [ 1.3283],
#         [ 1.3247],
#         [ 1.3172],
#         [ 1.3213],
#         [ 1.3251],
#         [ 1.3258],
#         [ 1.3273],
#         [ 1.3243],
#         [ 1.3139],
#         [ 1.3095],
#         [ 1.3197],
#         [ 1.3133],
#         [ 1.3174],
#         [ 1.3228],
#         [ 1.3262],
#         [ 1.3202],
#         [ 1.3266],
#         [ 1.3241],
#         [ 1.3238],
#         [ 1.3216],
#         [ 1.3236],
#         [ 1.3161],
#         [ 1.305 ],
#         [ 1.2987],
#         [ 1.3114],
#         [ 1.3105],
#         [ 1.3135],
#         [ 1.315 ],
#         [ 1.3119],
#         [ 1.3118],
#         [ 1.314 ],
#         [ 1.3125],
#         [ 1.312 ],
#         [ 1.3035],
#         [ 1.3021],
#         [ 1.2947],
#         [ 1.2957],
#         [ 1.288 ],
#         [ 1.287 ],
#         [ 1.2769],
#         [ 1.2757],
#         [ 1.2738],
#         [ 1.2685],
#         [ 1.2722],
#         [ 1.2735],
#         [ 1.2765],
#         [ 1.286 ],
#         [ 1.291 ],
#         [ 1.283 ],
#         [ 1.2858],
#         [ 1.2891],
#         [ 1.2886],
#         [ 1.3006],
#         [ 1.2997],
#         [ 1.2964],
#         [ 1.2833],
#         [ 1.2903],
#         [ 1.2933],
#         [ 1.2934]])

# %%
X.shape
# Out:
# (577, 3)

# %%
X
# Out:
# matrix([[ 1.1207,  0.7215,  0.992 ],
#         [ 1.1192,  0.7203,  0.9919],
#         [ 1.1145,  0.7184,  0.993 ],
#         ...,
#         [ 1.162 ,  0.7189,  0.9716],
#         [ 1.1624,  0.7198,  0.9682],
#         [ 1.1572,  0.7135,  0.9684]])

# %% [markdown]
# ## Now we are trying to perform Linear Regression without using inbuilt regression models

# %% [markdown]
# ### We are initializing the varibales to be used in the regression

# %% [markdown]
# ### <font color = 'magenta'> T </font> <font color = 'green'>is the total number of samples in our dataset </font>
#
#
# #### T = 1 x 1

# %%
T = 577

# %%
T = np.matrix(T)
T
# Out:
# matrix([[577]])

# %% [markdown]
# ###  <font color = 'magenta'> mu </font> <font color = 'green'> is a matrix consisting of all the means of independent variables in our dataset </font>
#
#
# #### mu = 1 x 3

# %%
mu = np.matrix(np.array([np.mean(fd['DEXUSEU']),np.mean(fd['DEXUSAL']),np.mean(fd['DEXSZUS'])]))
mu
# Out:
# matrix([[ 1.14269393,  0.76085407,  0.98132686]])

# %% [markdown]
# ###  <font color = 'magenta'> cov </font> <font color = 'green'> is a matrix consisting of the covariance of the co-relation between independent variables </font>
#
#
# #### cov = 587 x 587

# %%
cov = np.cov(X, mu)
cov = np.matrix(cov)
cov
# Out:
# matrix([[ 0.04151576,  0.04151536,  0.04133991, ...,  0.04481194,
#           0.04506234,  0.03880605],
#         [ 0.04151536,  0.04151551,  0.0413421 , ...,  0.04479004,
#           0.04504283,  0.03878973],
#         [ 0.04133991,  0.0413421 ,  0.0411771 , ...,  0.04451997,
#           0.04478072,  0.03856578],
#         ...,
#         [ 0.04481194,  0.04479004,  0.04451997, ...,  0.04921849,
#           0.04939396,  0.04251754],
#         [ 0.04506234,  0.04504283,  0.04478072, ...,  0.04939396,
#           0.04958152,  0.04268116],
#         [ 0.03880605,  0.03878973,  0.03856578, ...,  0.04251754,
#           0.04268116,  0.03674154]])

# %% [markdown]
# ## Implementing Ordinary Least Squares Regression (OLS)
#
# #### Y = alpha + beta*X
#
# #### Y         -  dependent variable
# #### alpha  -  constant term (a matrix of ones)
# #### X         -  independent variable
# #### beta    -  co-relation of the independent variables w.r.t Y
#
# ###  Calculating <font color='magenta'>beta_hat</font> which is the predected co-realtion of the independent variable
# #### beta_hat = 3 x 1

# %%
from numpy import dot
from numpy.linalg import inv
beta_hat = (inv((X.T)*X))*(X.T)*(Y)
beta_hat = np.matrix(beta_hat)
beta_hat
# Out:
# matrix([[ 0.98597612],
#         [-0.24446519],
#         [ 0.37994265]])

# %% [markdown]
# ###  Calculating <font color='magenta'>Y_hat</font> which is the predective value of Y_t (dependent variable)using OLS
#
# #### Y_hat = 577 x 1

# %%
#Y_hat = np.dot(X, beta_hat)

Y_hat = (X*beta_hat)
Y_hat = np.matrix(Y_hat)
Y_hat
# Out:
# matrix([[ 1.30550491],
#         [ 1.30428131],
#         [ 1.30052964],
#         [ 1.30053225],
#         [ 1.30210793],
#         [ 1.29899136],
#         [ 1.29827774],
#         [ 1.29963991],
#         [ 1.29964666],
#         [ 1.30931984],
#         [ 1.30880626],
#         [ 1.30404601],
#         [ 1.30569423],
#         [ 1.30157698],
#         [ 1.29745841],
#         [ 1.29872128],
#         [ 1.29122317],
#         [ 1.2936672 ],
#         [ 1.28849979],
#         [ 1.29440206],
#         [ 1.29895848],
#         [ 1.29260379],
#         [ 1.29378081],
#         [ 1.29905912],
#         [ 1.28346637],
#         [ 1.2789369 ],
#         [ 1.28294247],
#         [ 1.28624559],
#         [ 1.27808216],
#         [ 1.28557238],
#         [ 1.28131627],
#         [ 1.28005586],
#         [ 1.27954894],
#         [ 1.27750675],
#         [ 1.27831417],
#         [ 1.28028397],
#         [ 1.282872  ],
#         [ 1.2813168 ],
#         [ 1.27855085],
#         [ 1.27952661],
#         [ 1.2769465 ],
#         [ 1.27733665],
#         [ 1.27784114],
#         [ 1.27490599],
#         [ 1.27524504],
#         [ 1.27631121],
#         [ 1.27853054],
#         [ 1.28279586],
#         [ 1.28353346],
#         [ 1.28438263],
#         [ 1.28707443],
#         [ 1.28488963],
#         [ 1.28107589],
#         [ 1.27849311],
#         [ 1.27888937],
#         [ 1.28107519],
#         [ 1.28356616],
#         [ 1.28203571],
#         [ 1.28404031],
#         [ 1.28535055],
#         [ 1.28930123],
#         [ 1.29051159],
#         [ 1.29349136],
#         [ 1.29495105],
#         [ 1.29472568],
#         [ 1.29394678],
#         [ 1.29141746],
#         [ 1.29346348],
#         [ 1.29103383],
#         [ 1.28889558],
#         [ 1.288803  ],
#         [ 1.28863923],
#         [ 1.29136586],
#         [ 1.28790558],
#         [ 1.28956704],
#         [ 1.28903328],
#         [ 1.29193992],
#         [ 1.29233081],
#         [ 1.29317884],
#         [ 1.29588299],
#         [ 1.29715981],
#         [ 1.29426278],
#         [ 1.2893852 ],
#         [ 1.28967482],
#         [ 1.28853431],
#         [ 1.28606574],
#         [ 1.28799189],
#         [ 1.28887443],
#         [ 1.29170334],
#         [ 1.28709886],
#         [ 1.28651359],
#         [ 1.28781469],
#         [ 1.2889249 ],
#         [ 1.28798525],
#         [ 1.29019114],
#         [ 1.28886925],
#         [ 1.28711534],
#         [ 1.28780882],
#         [ 1.28154514],
#         [ 1.27752875],
#         [ 1.27855704],
#         [ 1.27327597],
#         [ 1.27352791],
#         [ 1.27216442],
#         [ 1.26853177],
#         [ 1.26804601],
#         [ 1.26372237],
#         [ 1.26456702],
#         [ 1.26432622],
#         [ 1.2662736 ],
#         [ 1.26683113],
#         [ 1.2701696 ],
#         [ 1.27052784],
#         [ 1.27344279],
#         [ 1.27745775],
#         [ 1.2763603 ],
#         [ 1.27688416],
#         [ 1.27083028],
#         [ 1.26959116],
#         [ 1.26503818],
#         [ 1.26269748],
#         [ 1.25223778],
#         [ 1.25374379],
#         [ 1.25240707],
#         [ 1.25017372],
#         [ 1.24908911],
#         [ 1.24918386],
#         [ 1.25004063],
#         [ 1.24637631],
#         [ 1.24823616],
#         [ 1.24590301],
#         [ 1.25006506],
#         [ 1.24942668],
#         [ 1.25204378],
#         [ 1.25375981],
#         [ 1.25835607],
#         [ 1.25792237],
#         [ 1.26028987],
#         [ 1.25131572],
#         [ 1.24432002],
#         [ 1.24862738],
#         [ 1.24980936],
#         [ 1.25071798],
#         [ 1.23607217],
#         [ 1.2422711 ],
#         [ 1.2407033 ],
#         [ 1.23780006],
#         [ 1.24068666],
#         [ 1.24342539],
#         [ 1.24499223],
#         [ 1.24612082],
#         [ 1.2405172 ],
#         [ 1.24607202],
#         [ 1.2496754 ],
#         [ 1.24026907],
#         [ 1.24378773],
#         [ 1.24965475],
#         [ 1.24825075],
#         [ 1.24830998],
#         [ 1.24814885],
#         [ 1.24212476],
#         [ 1.25054793],
#         [ 1.2483813 ],
#         [ 1.25118119],
#         [ 1.24958162],
#         [ 1.24715774],
#         [ 1.25358759],
#         [ 1.25428999],
#         [ 1.2540869 ],
#         [ 1.24829037],
#         [ 1.24910039],
#         [ 1.24743398],
#         [ 1.2545964 ],
#         [ 1.25308269],
#         [ 1.25338852],
#         [ 1.25269265],
#         [ 1.24869015],
#         [ 1.24613767],
#         [ 1.24625128],
#         [ 1.24493411],
#         [ 1.24317511],
#         [ 1.24055562],
#         [ 1.23882266],
#         [ 1.23894788],
#         [ 1.24259772],
#         [ 1.24010658],
#         [ 1.23584588],
#         [ 1.23695921],
#         [ 1.23742327],
#         [ 1.23742135],
#         [ 1.24131431],
#         [ 1.23979202],
#         [ 1.23690528],
#         [ 1.23590153],
#         [ 1.24003673],
#         [ 1.24265036],
#         [ 1.24237495],
#         [ 1.24097428],
#         [ 1.24490973],
#         [ 1.25152804],
#         [ 1.24923371],
#         [ 1.2472954 ],
#         [ 1.24545238],
#         [ 1.24931993],
#         [ 1.25024859],
#         [ 1.24992463],
#         [ 1.25469741],
#         [ 1.25339484],
#         [ 1.25375833],
#         [ 1.25571093],
#         [ 1.26006702],
#         [ 1.25718447],
#         [ 1.25190642],
#         [ 1.24891579],
#         [ 1.2479414 ],
#         [ 1.24578404],
#         [ 1.24723664],
#         [ 1.24780912],
#         [ 1.24730678],
#         [ 1.24542248],
#         [ 1.24524558],
#         [ 1.24591773],
#         [ 1.2452314 ],
#         [ 1.24439414],
#         [ 1.24380367],
#         [ 1.24593773],
#         [ 1.25004825],
#         [ 1.25174646],
#         [ 1.25480923],
#         [ 1.24954928],
#         [ 1.26319776],
#         [ 1.27157169],
#         [ 1.39220552],
#         [ 1.38933811],
#         [ 1.38488052],
#         [ 1.38439283],
#         [ 1.38262863],
#         [ 1.37831072],
#         [ 1.37563567],
#         [ 1.37565349],
#         [ 1.37379962],
#         [ 1.37280573],
#         [ 1.36820969],
#         [ 1.36784406],
#         [ 1.37051204],
#         [ 1.37370619],
#         [ 1.37516678],
#         [ 1.3668421 ],
#         [ 1.35891659],
#         [ 1.36018473],
#         [ 1.35617189],
#         [ 1.35446555],
#         [ 1.35315943],
#         [ 1.34684072],
#         [ 1.34821571],
#         [ 1.3420721 ],
#         [ 1.33226495],
#         [ 1.34064789],
#         [ 1.33958952],
#         [ 1.34144856],
#         [ 1.341766  ],
#         [ 1.33951455],
#         [ 1.34762229],
#         [ 1.35158351],
#         [ 1.34959514],
#         [ 1.35163185],
#         [ 1.35059993],
#         [ 1.34999847],
#         [ 1.34113245],
#         [ 1.34155993],
#         [ 1.34107408],
#         [ 1.33898349],
#         [ 1.34062798],
#         [ 1.34040477],
#         [ 1.34141848],
#         [ 1.34710492],
#         [ 1.3463552 ],
#         [ 1.34080381],
#         [ 1.34129816],
#         [ 1.34742361],
#         [ 1.34302023],
#         [ 1.34539952],
#         [ 1.34974047],
#         [ 1.35210237],
#         [ 1.35231575],
#         [ 1.35101505],
#         [ 1.352216  ],
#         [ 1.3517436 ],
#         [ 1.35019612],
#         [ 1.35223745],
#         [ 1.34897257],
#         [ 1.3471752 ],
#         [ 1.34543537],
#         [ 1.3510471 ],
#         [ 1.35046967],
#         [ 1.34853408],
#         [ 1.34786569],
#         [ 1.34613047],
#         [ 1.34616244],
#         [ 1.34984031],
#         [ 1.34830369],
#         [ 1.34630369],
#         [ 1.34230158],
#         [ 1.33951666],
#         [ 1.33798653],
#         [ 1.33966273],
#         [ 1.33991891],
#         [ 1.3359936 ],
#         [ 1.32369839],
#         [ 1.32332722],
#         [ 1.31947174],
#         [ 1.31822545],
#         [ 1.3234556 ],
#         [ 1.32494615],
#         [ 1.3268813 ],
#         [ 1.33272541],
#         [ 1.33722009],
#         [ 1.33706658],
#         [ 1.34021102],
#         [ 1.34406137],
#         [ 1.34635327],
#         [ 1.34498963],
#         [ 1.33962348],
#         [ 1.33598692],
#         [ 1.33555872],
#         [ 1.3391105 ],
#         [ 1.33799307],
#         [ 1.33448211]])

# %% [markdown]
# ### Below we are attaching a column <font color = 'red'>'Pred_DEXUSUK'</font> which is the predicted forex rates of UK w.r.t US
# ### which is derived from the beta_hat(covariance and co-relation) of the X(independent variables)

# %%
pred_df=fd
pred_df['Pred_DEXUSUK']=Y_hat
pred_df
# Out:
#     observation_date  DEXINUS  DEXCHUS  DEXMXUS  DEXBZUS  DEXUSEU  DEXUSUK  \
# 0         2016-05-20    67.42   6.5485  18.3770   3.5386   1.1207   1.4513
# 1         2016-05-23    67.47   6.5533  18.4710   3.5753   1.1192   1.4444
# 2         2016-05-24    67.59   6.5552  18.4435   3.5518   1.1145   1.4623
# 575   0.7406   0.9926      1.339517
# 576   0.7393   0.9963      1.337987
# 577   0.7428   0.9944      1.339663
# 578   0.7420   0.9943      1.339919
# 579   0.7394   0.9906      1.335994
# 580   0.7298   0.9954      1.323698
# 581   0.7270   0.9934      1.323327
# 582   0.7240   0.9930      1.319472
# 583   0.7233   0.9942      1.318225
# 584   0.7276   0.9962      1.323456
# 585   0.7282   0.9948      1.324946
# 586   0.7308   0.9943      1.326881
# 587   0.7352   0.9876      1.332725
# 588   0.7352   0.9836      1.337220
# 589   0.7264   0.9848      1.337067
# 590   0.7332   0.9824      1.340211
# 591   0.7346   0.9802      1.344061
# 592   0.7352   0.9752      1.346353
# 593   0.7292   0.9732      1.344990
# 594   0.7262   0.9709      1.339623
# 595   0.7192   0.9698      1.335987
# 597   0.7174   0.9753      1.335559
# 598   0.7189   0.9716      1.339111
# 599   0.7198   0.9682      1.337993
# 600   0.7135   0.9684      1.334482
#
# [577 rows x 10 columns]

# %%
fig = plt.figure(figsize=(15,7))
plt.plot(fd['observation_date'], fd['DEXUSUK'], label = 'ACTUAL', color = 'blue')
plt.plot(fd['observation_date'], fd['Pred_DEXUSUK'], label = 'PREDICTED', color = 'red')
plt.title('Predicted forex rates of UK Pounds w.r.t US Dollars')
plt.xlabel('Years - - - - - - - - - - >')
plt.ylabel('Price  - - - - - - - - - - >')
plt.legend()
plt.show()

# %% [markdown]
# #### Analysis : We observe that UK's economy has under performed from (1.451) in 2016 to (1.293) in 2018 primarily due to the brexit on March 29, 2017.
# #### From the covariance of the other independent countires such as australia, switzerland & europe, we observe that our prediction is most of the time under the actual curve. Therefore, under predicted.

# %% [markdown]
# ### <font color = 'green'>the difference between the observed value of the dependent variable (y) and the predicted value (ŷ) is called the residual </font>

# %%
residuals = Y-Y_hat #Residuals from OLS: Y - X*beta
residuals = np.matrix(residuals)
residuals
# Out:
# matrix([[  1.45795093e-01],
#         [  1.40118693e-01],
#         [  1.61770360e-01],
#         [  1.68867748e-01],
#         [  1.65192070e-01],
#         [  1.65408645e-01],
#         [  1.54722257e-01],
#         [  1.39860088e-01],
#         [  1.42253335e-01],
#         [  1.42780158e-01],
#         [  1.36193735e-01],
#         [  1.52353985e-01],
#         [  1.48905765e-01],
#         [  1.45123021e-01],
#         [  1.36741591e-01],
#         [  1.23578719e-01],
#         [  1.21776830e-01],
#         [  1.24832796e-01],
#         [  1.19000208e-01],
#         [  1.34097940e-01],
#         [  1.69841518e-01],
#         [  1.74196210e-01],
#         [  1.74419194e-01],
#         [  1.80940876e-01],
#         [  8.04336276e-02],
#         [  4.27630986e-02],
#         [  4.64575276e-02],
#         [  6.47544080e-02],
#         [  4.61178354e-02],
#         [  4.25276152e-02],
#         [  2.07837288e-02],
#         [  1.20441376e-02],
#         [  1.30510562e-02],
#         [  1.62932501e-02],
#         [  2.02858293e-02],
#         [  4.34160346e-02],
#         [  3.51279990e-02],
#         [  5.18832034e-02],
#         [  4.08491512e-02],
#         [  4.83733882e-02],
#         [ -4.67983927e-02],
#         [ -4.76272171e-02],
#         [ -4.56717431e-02],
#         [ -4.97254453e-02],
#         [ -5.12555965e-02],
#         [ -5.14461452e-02],
#         [ -5.03812975e-02],
#         [ -4.67254056e-02],
#         [ -4.62200893e-02],
#         [ -5.40665811e-02],
#         [ -5.44110169e-02],
#         [ -5.49613700e-02],
#         [ -5.77532725e-02],
#         [ -4.43896286e-02],
#         [ -3.99234826e-02],
#         [ -3.95869215e-02],
#         [ -5.22587150e-02],
#         [ -4.88105005e-02],
#         [ -4.46930672e-02],
#         [ -4.10821107e-02]])

# %% [markdown]
# ### <font color = 'magenta'>sigma2</font>  is the variance of the difference between the dependent variable and its predicted value.
#
# #### sigma2 = 1 x 1

# %%
from numpy.linalg import inv              # variance of Y_t or residuals
sigma2 = ((1/T)*(residuals.T))*(residuals)
sigma2 = np.matrix(sigma2)
sigma2
# Out:
# matrix([[ 0.00156726]])

# %% [markdown]
# ### <font color ='magenta'>sig</font> is the standard deviation of the  difference between the dependent variable and its predicted value.
#
# #### sig = 1 x 1

# %%
from numpy import sqrt
sig = sqrt(sigma2);                      # standard deviation of Y_t or residuals
sig = np.matrix(sig)
sig
# Out:
# matrix([[ 0.03958868]])

# %% [markdown]
# ### <font color ='magenta'>varcov_beta_hat</font> is the difference between the variance (difference between the dependent variable and its predicted value) and the covariance matrix  beat_hat (co-relation between independent variables w.r.t dependent variable)

# %%
varcov_beta_hat = (sigma2)*(inv((X.reshape(1731, 1).T)*(X.reshape(1731, 1))))
varcov_beta_hat = np.matrix(varcov_beta_hat)
varcov_beta_hat
# Out:
# matrix([[  9.52568181e-07]])

# %%
X.reshape(1731, 1).shape
# Out:
# (1731, 1)

# %%
from numpy import diag
var_beta_hat = sqrt(T*diag(varcov_beta_hat))    #N x 1
var_beta_hat = np.matrix(var_beta_hat)
var_beta_hat
# Out:
# matrix([[ 0.02344423]])

# %% [markdown]
# ###  <font color ='magenta'>R square</font> is calculated below and comes to <font color ='magenta'>0.0494</font>

# %%
from numpy import var
R_square = (1 - residuals.T*residuals)/(T*var(Y))
R_square = np.matrix(R_square)
R_square
# Out:
# matrix([[ 0.04949346]])

# %% [markdown]
# ### Similarly, <font color ='magenta'>Adjusted R square</font> is calculated below and comes to <font color ='magenta'>0.0461</font>

# %%
from numpy import size
N = np.size(X, 1)
adj_R_square = 1-(1-R_square)*(T-1)/(T-N);
adj_R_square
# Out:
# matrix([[ 0.04618159]])

# %% [markdown]
# ### <font color ='magenta'>t-test score</font> is generated into a matrix of size (3 x 1) below:

# %%
# Test Each Coefficient: beta_i
t_stat = (beta_hat)/(var_beta_hat)
t_stat
# Out:
# matrix([[ 42.05624113],
#         [-10.42752144],
#         [ 16.20623399]])

# %% [markdown]
# ### Here we are setting the <font color = 'magenta'>significance level</font> of the OLS regression into a matrix of 3 x1 using the <font color = 'red'>Normal cumulative distribution function</font>

# %%
from scipy.stats import norm
p_val_t = 1-norm.cdf(t_stat)
p_val_t = np.matrix(p_val_t)
p_val_t
# Out:
# matrix([[ 0.],
#         [ 1.],
#         [ 0.]])

# %% [markdown]
# ### Test of Joint Significance of Model
#
# #### F-stat matrix of 3 x 3

# %%
#F_stat = beta_hat'*varcov_beta_hat*beta_hat/(residuals'*residuals)
#  size:   (1 x N)*    (N x N)*      (N x 1)/((1 x T) *   (T x 1)) = 1 x 1
#  size:   (1 x N)*    (N x N)*      (N x 1)/((1 x T) *   (T x 1)) = 1 x 1
F_stat = ((beta_hat)*(varcov_beta_hat)*(beta_hat.T))/((residuals.T)*(residuals))
F_stat
# Out:
# matrix([[  1.02402604e-06,  -2.53899379e-07,   3.94605062e-07],
#         [ -2.53899379e-07,   6.29523978e-08,  -9.78392894e-08],
#         [  3.94605062e-07,  -9.78392894e-08,   1.52059761e-07]])

# %% [markdown]
# ### Below we are calculating the <font color = "magenta">P value matrix</font> for the significance level matrix defined above using the <font color = 'red'>Chi-Square cumulative distribution function</font>

# %%
from scipy import stats
p_val_F = 1-stats.chi2.cdf(F_stat,T-N)
p_val_F = np.matrix(p_val_F)
p_val_F
# Out:
# matrix([[ 1.,  1.,  1.],
#         [ 1.,  1.,  1.],
#         [ 1.,  1.,  1.]])

# %%
from sklearn import linear_model
import statsmodels.api as sm
from statsmodels import regression



# Load pricing data for an asset
start = '2016-06-20'
end = '2018-09-07'
data = try_2
prices = data['DEXUSUK']
dates = prices.index

# Plot the price of the asset over time
plt.figure(figsize=(15,7))
plt.plot(try_2['observation_date'],try_2['DEXUSUK'])

# Find the line of best fit to illustrate the trend
X = np.arange(len(dates))
x = sm.add_constant(X) # Add a column of ones so that line can have a y-intercept
model = regression.linear_model.OLS(try_2['DEXUSUK'], x).fit()
a = model.params[0] # Get coefficients of line
b = model.params[1]
trend = X * b + a
plt.plot(try_2['observation_date'],trend, 'r', alpha=0.9)
plt.ylabel('UK Pounds w.r.t USD')
plt.xlabel('Years')
plt.legend(['UK Pounds', 'Trendline'])
plt.show()

# %% [markdown]
# # Bollinger Bands

# %% [markdown]
# ### For this we will be setting the short and long <font color = 'red'>MOVING AVERAGE, UPPER BAND, and LOWER BAND</font>
#
#
# ### The <font color = 'magenta'>short moving average</font> is of a period of <font color = 'magenta'>5</font> working days in a week.

# %%
short_MA = pred_df['Pred_DEXUSUK'].rolling(window=5).mean()
pred_df['Short_Moving_Avg'] = short_MA
pred_df.tail()
# Out:
#     observation_date  DEXINUS  DEXCHUS  DEXMXUS  DEXBZUS  DEXUSEU  DEXUSUK  \
# 595       2018-08-31    71.00   6.8300  19.2135   4.1280   1.1596   1.2964
# 597       2018-09-04    71.58   6.8427  19.3505   4.1560   1.1566   1.2833
# 598       2018-09-05    71.75   6.8270  19.4270   4.1589   1.1620   1.2903
# 599       2018-09-06    71.94   6.8322  19.3610   4.1462   1.1624   1.2933
# 600       2018-09-07    71.78   6.8419  19.2110   4.0594   1.1572   1.2934
#
#      DEXUSAL  DEXSZUS  Pred_DEXUSUK  Short_Moving_Avg
# 595   0.7192   0.9698      1.335987          1.342203
# 597   0.7174   0.9753      1.335559          1.340502
# 598   0.7189   0.9716      1.339111          1.339054
# 599   0.7198   0.9682      1.337993          1.337655
# 600   0.7135   0.9684      1.334482          1.336626

# %% [markdown]
# ### Similarly, The <font color = 'magenta'>long moving average</font> is of a period of <font color = 'magenta'>20</font> working days in a month.

# %%
long_MA = pred_df['Pred_DEXUSUK'].rolling(window=20).mean()
pred_df['Long_Moving_Avg'] = long_MA
pred_df.tail()
# Out:
#     observation_date  DEXINUS  DEXCHUS  DEXMXUS  DEXBZUS  DEXUSEU  DEXUSUK  \
# 595       2018-08-31    71.00   6.8300  19.2135   4.1280   1.1596   1.2964
# 597       2018-09-04    71.58   6.8427  19.3505   4.1560   1.1566   1.2833
# 598       2018-09-05    71.75   6.8270  19.4270   4.1589   1.1620   1.2903
# 599       2018-09-06    71.94   6.8322  19.3610   4.1462   1.1624   1.2933
# 600       2018-09-07    71.78   6.8419  19.2110   4.0594   1.1572   1.2934
#
#      DEXUSAL  DEXSZUS  Pred_DEXUSUK  Short_Moving_Avg  Long_Moving_Avg
# 595   0.7192   0.9698      1.335987          1.342203         1.333590
# 597   0.7174   0.9753      1.335559          1.340502         1.333469
# 598   0.7189   0.9716      1.339111          1.339054         1.333441
# 599   0.7198   0.9682      1.337993          1.337655         1.333345
# 600   0.7135   0.9684      1.334482          1.336626         1.333269

# %% [markdown]
# ### Now, Calculating the <font color = 'magenta'>Standard Deviation</font> of the <font color = 'red'>long moving average</font> for determining the variance and account for the <font color = 'red'>volitility</font> used in the bollinger band for stock trading.

# %%
long_std= pred_df['Pred_DEXUSUK'].rolling(window=20).std()
pred_df['Long_volatility'] = long_std
pred_df.tail()
# Out:
#     observation_date  DEXINUS  DEXCHUS  DEXMXUS  DEXBZUS  DEXUSEU  DEXUSUK  \
# 595       2018-08-31    71.00   6.8300  19.2135   4.1280   1.1596   1.2964
# 597       2018-09-04    71.58   6.8427  19.3505   4.1560   1.1566   1.2833
# 598       2018-09-05    71.75   6.8270  19.4270   4.1589   1.1620   1.2903
# 599       2018-09-06    71.94   6.8322  19.3610   4.1462   1.1624   1.2933
# 600       2018-09-07    71.78   6.8419  19.2110   4.0594   1.1572   1.2934
#
#      DEXUSAL  DEXSZUS  Pred_DEXUSUK  Short_Moving_Avg  Long_Moving_Avg  \
# 595   0.7192   0.9698      1.335987          1.342203         1.333590
# 597   0.7174   0.9753      1.335559          1.340502         1.333469
# 598   0.7189   0.9716      1.339111          1.339054         1.333441
# 599   0.7198   0.9682      1.337993          1.337655         1.333345
# 600   0.7135   0.9684      1.334482          1.336626         1.333269
#
#      Long_volatility
# 595         0.008818
# 597         0.008771
# 598         0.008752
# 599         0.008687
# 600         0.008669

# %% [markdown]
# ### Now, we will calculate the <font color = 'magenta'>Upper and Lower Bands</font> for Buying and selling signals in Stock Trading
#
#
#
# ### <font color = 'green'>Upper Band:</font> The upper band is simply two standard deviations above the moving average of a stock’s price.
# ### <font color = 'green'>Upper Band:</font>  = 20 day moving average + (20 Day standard deviation of price x 2)

# %%
long_upper_band = (long_MA) + ((long_std)*2)
pred_df['Long_Upper_Band'] = long_upper_band
pred_df.tail()
# Out:
#     observation_date  DEXINUS  DEXCHUS  DEXMXUS  DEXBZUS  DEXUSEU  DEXUSUK  \
# 595       2018-08-31    71.00   6.8300  19.2135   4.1280   1.1596   1.2964
# 597       2018-09-04    71.58   6.8427  19.3505   4.1560   1.1566   1.2833
# 598       2018-09-05    71.75   6.8270  19.4270   4.1589   1.1620   1.2903
# 599       2018-09-06    71.94   6.8322  19.3610   4.1462   1.1624   1.2933
# 600       2018-09-07    71.78   6.8419  19.2110   4.0594   1.1572   1.2934
#
#      DEXUSAL  DEXSZUS  Pred_DEXUSUK  Short_Moving_Avg  Long_Moving_Avg  \
# 595   0.7192   0.9698      1.335987          1.342203         1.333590
# 597   0.7174   0.9753      1.335559          1.340502         1.333469
# 598   0.7189   0.9716      1.339111          1.339054         1.333441
# 599   0.7198   0.9682      1.337993          1.337655         1.333345
# 600   0.7135   0.9684      1.334482          1.336626         1.333269
#
#      Long_volatility  Long_Upper_Band
# 595         0.008818         1.351227
# 597         0.008771         1.351012
# 598         0.008752         1.350945
# 599         0.008687         1.350719
# 600         0.008669         1.350608

# %% [markdown]
# ### <font color = 'red'>Lower Band:</font> Two standard deviations below the moving average is the lower band.
# ### <font color = 'red'>Lower Band:</font> = 20 day moving average - (20 Day standard deviation of price x 2)

# %%
long_lower_band = (long_MA) - ((long_std)*2)
pred_df['Long_Lower_Band'] = long_lower_band
pred_df.tail()
# Out:
#     observation_date  DEXINUS  DEXCHUS  DEXMXUS  DEXBZUS  DEXUSEU  DEXUSUK  \
# 595       2018-08-31    71.00   6.8300  19.2135   4.1280   1.1596   1.2964
# 597       2018-09-04    71.58   6.8427  19.3505   4.1560   1.1566   1.2833
# 598       2018-09-05    71.75   6.8270  19.4270   4.1589   1.1620   1.2903
# 599       2018-09-06    71.94   6.8322  19.3610   4.1462   1.1624   1.2933
# 600       2018-09-07    71.78   6.8419  19.2110   4.0594   1.1572   1.2934
#
#      DEXUSAL  DEXSZUS  Pred_DEXUSUK  Short_Moving_Avg  Long_Moving_Avg  \
# 595   0.7192   0.9698      1.335987          1.342203         1.333590
# 597   0.7174   0.9753      1.335559          1.340502         1.333469
# 598   0.7189   0.9716      1.339111          1.339054         1.333441
# 599   0.7198   0.9682      1.337993          1.337655         1.333345
# 600   0.7135   0.9684      1.334482          1.336626         1.333269
#
#      Long_volatility  Long_Upper_Band  Long_Lower_Band
# 595         0.008818         1.351227         1.315953
# 597         0.008771         1.351012         1.315926
# 598         0.008752         1.350945         1.315938
# 599         0.008687         1.350719         1.315971
# 600         0.008669         1.350608         1.315931

# %%
pred_df[[ 'Pred_DEXUSUK', 'Long_Moving_Avg', 'Long_Upper_Band', 'Long_Lower_Band']].plot(figsize=(15,7))
plt.title('20 Day Bollinger Band for UK Pounds w.r.t USD')
plt.xlabel('Time (Years)----------------------------------------------------->')
plt.ylabel('Price (USD)----------------------------------------------------->')
plt.show()

# %%
plt.style.use('fivethirtyeight')
fig = plt.figure(figsize=(15,7))
ax = fig.add_subplot(111)
x_axis = pred_df.index.get_level_values(0)
ax.fill_between(x_axis, pred_df['Long_Upper_Band'], pred_df['Long_Lower_Band'], color='silver')
ax.plot(x_axis, pred_df['Pred_DEXUSUK'], color='black', lw=2)
ax.plot(x_axis, pred_df['Long_Moving_Avg'], color='yellow', lw=2)
ax.plot(x_axis, pred_df['Short_Moving_Avg'], color='white', lw=2)
ax.set_title('20 Day Bollinger Band for UK Pounds w.r.t USD')
ax.set_xlabel('Date (Year/Month)')
ax.set_ylabel('Price(USD)')
ax.legend()
plt.show()

# %% [markdown]
# #### Here the grey area shows the volatility of the UK pounds over 3 years from 2016 to 2018

# %% [markdown]
# ## Trying 10 day moving average for better trading accuracy

# %%
try_2 = pred_df
med_MA = try_2['Pred_DEXUSUK'].rolling(window=10).mean()
try_2['Med_Moving_Avg'] = med_MA
try_2.tail()
# Out:
#     observation_date  DEXINUS  DEXCHUS  DEXMXUS  DEXBZUS  DEXUSEU  DEXUSUK  \
# 595       2018-08-31    71.00   6.8300  19.2135   4.1280   1.1596   1.2964
# 597       2018-09-04    71.58   6.8427  19.3505   4.1560   1.1566   1.2833
# 598       2018-09-05    71.75   6.8270  19.4270   4.1589   1.1620   1.2903
# 599       2018-09-06    71.94   6.8322  19.3610   4.1462   1.1624   1.2933
# 600       2018-09-07    71.78   6.8419  19.2110   4.0594   1.1572   1.2934
#
#      DEXUSAL  DEXSZUS  Pred_DEXUSUK  Short_Moving_Avg  Long_Moving_Avg  \
# 595   0.7192   0.9698      1.335987          1.342203         1.333590
# 597   0.7174   0.9753      1.335559          1.340502         1.333469
# 598   0.7189   0.9716      1.339111          1.339054         1.333441
# 599   0.7198   0.9682      1.337993          1.337655         1.333345
# 600   0.7135   0.9684      1.334482          1.336626         1.333269
#
#      Long_volatility  Long_Upper_Band  Long_Lower_Band  Med_Moving_Avg
# 595         0.008818         1.351227         1.315953        1.338512
# 597         0.008771         1.351012         1.315926        1.339380
# 598         0.008752         1.350945         1.315938        1.340018
# 599         0.008687         1.350719         1.315971        1.340095
# 600         0.008669         1.350608         1.315931        1.339837

# %%
med_std= try_2['Pred_DEXUSUK'].rolling(window=10).std()
try_2['Med_volatility'] = med_std
try_2.tail()
# Out:
#     observation_date  DEXINUS  DEXCHUS  DEXMXUS  DEXBZUS  DEXUSEU  DEXUSUK  \
# 595       2018-08-31    71.00   6.8300  19.2135   4.1280   1.1596   1.2964
# 597       2018-09-04    71.58   6.8427  19.3505   4.1560   1.1566   1.2833
# 598       2018-09-05    71.75   6.8270  19.4270   4.1589   1.1620   1.2903
# 599       2018-09-06    71.94   6.8322  19.3610   4.1462   1.1624   1.2933
# 600       2018-09-07    71.78   6.8419  19.2110   4.0594   1.1572   1.2934
#
#      DEXUSAL  DEXSZUS  Pred_DEXUSUK  Short_Moving_Avg  Long_Moving_Avg  \
# 595   0.7192   0.9698      1.335987          1.342203         1.333590
# 597   0.7174   0.9753      1.335559          1.340502         1.333469
# 598   0.7189   0.9716      1.339111          1.339054         1.333441
# 599   0.7198   0.9682      1.337993          1.337655         1.333345
# 600   0.7135   0.9684      1.334482          1.336626         1.333269
#
#      Long_volatility  Long_Upper_Band  Long_Lower_Band  Med_Moving_Avg  \
# 595         0.008818         1.351227         1.315953        1.338512
# 597         0.008771         1.351012         1.315926        1.339380
# 598         0.008752         1.350945         1.315938        1.340018
# 599         0.008687         1.350719         1.315971        1.340095
# 600         0.008669         1.350608         1.315931        1.339837
#
#      Med_volatility
# 595        0.005937
# 597        0.004511
# 598        0.003871
# 599        0.003817
# 600        0.004120

# %%
med_upper_band = (med_MA) + ((med_std)*2)
try_2['Med_Upper_Band'] = med_upper_band
try_2.tail()
# Out:
#     observation_date  DEXINUS  DEXCHUS  DEXMXUS  DEXBZUS  DEXUSEU  DEXUSUK  \
# 595       2018-08-31    71.00   6.8300  19.2135   4.1280   1.1596   1.2964
# 597       2018-09-04    71.58   6.8427  19.3505   4.1560   1.1566   1.2833
# 598       2018-09-05    71.75   6.8270  19.4270   4.1589   1.1620   1.2903
# 599       2018-09-06    71.94   6.8322  19.3610   4.1462   1.1624   1.2933
# 600       2018-09-07    71.78   6.8419  19.2110   4.0594   1.1572   1.2934
#
#      DEXUSAL  DEXSZUS  Pred_DEXUSUK  Short_Moving_Avg  Long_Moving_Avg  \
# 595   0.7192   0.9698      1.335987          1.342203         1.333590
# 597   0.7174   0.9753      1.335559          1.340502         1.333469
# 598   0.7189   0.9716      1.339111          1.339054         1.333441
# 599   0.7198   0.9682      1.337993          1.337655         1.333345
# 600   0.7135   0.9684      1.334482          1.336626         1.333269
#
#      Long_volatility  Long_Upper_Band  Long_Lower_Band  Med_Moving_Avg  \
# 595         0.008818         1.351227         1.315953        1.338512
# 597         0.008771         1.351012         1.315926        1.339380
# 598         0.008752         1.350945         1.315938        1.340018
# 599         0.008687         1.350719         1.315971        1.340095
# 600         0.008669         1.350608         1.315931        1.339837
#
#      Med_volatility  Med_Upper_Band
# 595        0.005937        1.350386
# 597        0.004511        1.348402
# 598        0.003871        1.347761
# 599        0.003817        1.347729
# 600        0.004120        1.348077

# %%
med_lower_band = (med_MA) - ((med_std)*2)
try_2['Med_Lower_Band'] = med_lower_band
try_2.tail()
# Out:
#     observation_date  DEXINUS  DEXCHUS  DEXMXUS  DEXBZUS  DEXUSEU  DEXUSUK  \
# 595       2018-08-31    71.00   6.8300  19.2135   4.1280   1.1596   1.2964
# 597       2018-09-04    71.58   6.8427  19.3505   4.1560   1.1566   1.2833
# 598       2018-09-05    71.75   6.8270  19.4270   4.1589   1.1620   1.2903
# 599       2018-09-06    71.94   6.8322  19.3610   4.1462   1.1624   1.2933
# 600       2018-09-07    71.78   6.8419  19.2110   4.0594   1.1572   1.2934
#
#      DEXUSAL  DEXSZUS  Pred_DEXUSUK  Short_Moving_Avg  Long_Moving_Avg  \
# 595   0.7192   0.9698      1.335987          1.342203         1.333590
# 597   0.7174   0.9753      1.335559          1.340502         1.333469
# 598   0.7189   0.9716      1.339111          1.339054         1.333441
# 599   0.7198   0.9682      1.337993          1.337655         1.333345
# 600   0.7135   0.9684      1.334482          1.336626         1.333269
#
#      Long_volatility  Long_Upper_Band  Long_Lower_Band  Med_Moving_Avg  \
# 595         0.008818         1.351227         1.315953        1.338512
# 597         0.008771         1.351012         1.315926        1.339380
# 598         0.008752         1.350945         1.315938        1.340018
# 599         0.008687         1.350719         1.315971        1.340095
# 600         0.008669         1.350608         1.315931        1.339837
#
#      Med_volatility  Med_Upper_Band  Med_Lower_Band
# 595        0.005937        1.350386        1.326637
# 597        0.004511        1.348402        1.330357
# 598        0.003871        1.347761        1.332275
# 599        0.003817        1.347729        1.332462
# 600        0.004120        1.348077        1.331597

# %%
plt.style.use('fivethirtyeight')
fig = plt.figure(figsize=(15,7))
ax = fig.add_subplot(111)
x_axis = try_2.index.get_level_values(0)
ax.fill_between(x_axis, try_2['Med_Upper_Band'], try_2['Med_Lower_Band'], color='silver')
ax.plot(x_axis, try_2['Pred_DEXUSUK'], color='black', lw=2)
ax.plot(x_axis, try_2['Med_Moving_Avg'], color='yellow', lw=2)
ax.plot(x_axis, try_2['Short_Moving_Avg'], color='white', lw=2)
ax.set_title('10 Day Bollinger Band for UK Pounds w.r.t USD')
ax.set_xlabel('Date (Year/Month)')
ax.set_ylabel('Price(USD)')
ax.legend()
plt.show()

# %% [markdown]
# ### Momentum trading and momentum indicators are based on the notion that strong price movements in a particular direction are a likely indication that a price trend will continue in that direction. Similarly, weakening movements indicate that a trend has lost strength and could be headed for a reversal.

# %% [markdown]
# ## In financial markets, momentum is determined by other factors like trading volume and rate of price changes.

# %% [markdown]
# ## <font color = 'magenta'>Relative momentum strategy </font><font color = 'green'>- is where the performance of different securities within a particular asset class are compared against one another, and investors will favour buying strong performing securities and selling weak performing securities.</font>
#
#
#
#
#
#
#
#
# ## <font color = 'magenta'>Absolute momentum strategy </font><font color = 'green'> is where the behaviour of the price of a security is compared against its previous performance in a historical time series.</font>

# %% [markdown]
# ## Mean Reversion
#
#
# ### In a mean reversion model one hypothesizes that past upward trends are simply temporary overvaluings and the price will return to normal

# %%
#dates = try_2['observation_date']
plt.figure(figsize=(15,7))
plt.plot((try_2['DEXUSUK'] - try_2['Pred_DEXUSUK']).values)
plt.hlines(np.mean(try_2['DEXUSUK'] - try_2['Pred_DEXUSUK']), 0, len(try_2['observation_date']), colors='r')
plt.hlines(np.std(try_2['DEXUSUK'] - try_2['Pred_DEXUSUK']), 0, len(try_2['observation_date']), colors='r', linestyles='dashed')
plt.hlines(-np.std(try_2['DEXUSUK'] - try_2['Pred_DEXUSUK']), 0, len(try_2['observation_date']), colors='r', linestyles='dashed')
plt.xlabel('Numer of Observations Over Time')
plt.ylabel('UK Pounds w.r.t USD')
plt.title('Mean Reversion analysis of UK Pounds w.r.t USD')
plt.show()
